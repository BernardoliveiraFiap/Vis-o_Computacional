# %%
# !pip install tensorFlow
# !pip install pillow

# %%
# !pip install opencv-python

# %%
#Reconhecer Dolar
from google.colab.patches import cv2_imshow
from keras.models import load_model
import cv2
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/keras_model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# Substitua 'caminho_para_sua_imagem' pelo caminho da imagem que você deseja usar
image_path = '/content/dolar.png'
image = cv2.imread(image_path)

# Verifique se a imagem não é None
if image is not None:
    # Redimensione a imagem bruta para (224-altura,224-largura) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Mostre a imagem em uma janela
    cv2_imshow(image)

    # Transforme a imagem em um array numpy e reformate-a para a forma de entrada do modelo.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize o array da imagem
    image = (image / 127.5) - 1

    # Faça a previsão com o modelo
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Imprima a previsão e a pontuação de confiança
    print("Classe:", class_name[2:], end="")
    print("Pontuação de Confiança:", str(np.round(confidence_score * 100))[:-2], "%")

    # Escute o teclado para pressionamentos.
    keyboard_input = cv2.waitKey(0)

    # 27 é o ASCII para a tecla esc no seu teclado.
    if keyboard_input == 27:
        cv2.destroyAllWindows()
else:
    print("Não foi possível carregar a imagem.")
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# 1/1 [==============================] - 2s 2s/step
# Classe: Dolar
# Pontuação de Confiança: 100 %

# %%
#Reconhecer Real
from google.colab.patches import cv2_imshow
from keras.models import load_model
import cv2
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/keras_model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# Substitua 'caminho_para_sua_imagem' pelo caminho da imagem que você deseja usar
image_path = '/content/Real.png'
image = cv2.imread(image_path)

# Verifique se a imagem não é None
if image is not None:
    # Redimensione a imagem bruta para (224-altura,224-largura) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Mostre a imagem em uma janela
    cv2_imshow(image)

    # Transforme a imagem em um array numpy e reformate-a para a forma de entrada do modelo.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize o array da imagem
    image = (image / 127.5) - 1

    # Faça a previsão com o modelo
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Imprima a previsão e a pontuação de confiança
    print("Classe:", class_name[2:], end="")
    print("Pontuação de Confiança:", str(np.round(confidence_score * 100))[:-2], "%")

    # Escute o teclado para pressionamentos.
    keyboard_input = cv2.waitKey(0)

    # 27 é o ASCII para a tecla esc no seu teclado.
    if keyboard_input == 27:
        cv2.destroyAllWindows()
else:
    print("Não foi possível carregar a imagem.")
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# 1/1 [==============================] - 1s 913ms/step
# Classe: Real
# Pontuação de Confiança: 88 %

# %%
#Reconhecer fundo
#Reconhecer Real
from google.colab.patches import cv2_imshow
from keras.models import load_model
import cv2
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("/content/keras_model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# Substitua 'caminho_para_sua_imagem' pelo caminho da imagem que você deseja usar
image_path = '/content/fundo.jpg'
image = cv2.imread(image_path)

# Verifique se a imagem não é None
if image is not None:
    # Redimensione a imagem bruta para (224-altura,224-largura) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Mostre a imagem em uma janela
    cv2_imshow(image)

    # Transforme a imagem em um array numpy e reformate-a para a forma de entrada do modelo.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize o array da imagem
    image = (image / 127.5) - 1

    # Faça a previsão com o modelo
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Imprima a previsão e a pontuação de confiança
    print("Classe:", class_name[2:], end="")
    print("Pontuação de Confiança:", str(np.round(confidence_score * 100))[:-2], "%")

    # Escute o teclado para pressionamentos.
    keyboard_input = cv2.waitKey(0)

    # 27 é o ASCII para a tecla esc no seu teclado.
    if keyboard_input == 27:
        cv2.destroyAllWindows()
else:
    print("Não foi possível carregar a imagem.")
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# 1/1 [==============================] - 1s 1s/step
# Classe: Fundo
# Pontuação de Confiança: 99 %
